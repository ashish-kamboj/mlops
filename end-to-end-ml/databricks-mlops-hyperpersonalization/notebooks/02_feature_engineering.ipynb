# %%
# !pip install -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt
dbutils.library.restartPython()
# Out:
# Requirement already satisfied: numpy==1.26.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: pandas==2.3.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 3)) (2.3.3)
# Requirement already satisfied: scikit-learn==1.7.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 4)) (1.7.2)
# Requirement already satisfied: matplotlib==3.10.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (3.10.7)
# Requirement already satisfied: seaborn==0.13.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 6)) (0.13.2)
# Requirement already satisfied: plotly==5.24.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 7)) (5.24.1)
# Requirement already satisfied: pyyaml==6.0.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 8)) (6.0.3)
# Collecting pyarrow==20.0.0
#   Downloading pyarrow-20.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (42.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 MB 28.9 MB/s eta 0:00:00
# Collecting mlflow==3.0.1
#   Downloading mlflow-3.0.1-py3-none-any.whl (24.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 19.6 MB/s eta 0:00:00
# Requirement already satisfied: shap==0.49.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (0.49.1)
# Requirement already satisfied: xgboost==2.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 23)) (2.1.0)
# Requirement already satisfied: evidently==0.6.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.6.1)
# Requirement already satisfied: python-dateutil==2.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 30)) (2.9.0)
# Requirement already satisfied: tqdm==4.67.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 31)) (4.67.1)
# Requirement already satisfied: joblib==1.5.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 32)) (1.5.2)
# Requirement already satisfied: papermill==2.5.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (2.5.0)
# Requirement already satisfied: tzdata>=2022.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from pandas==2.3.3->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.10/site-packages (from pandas==2.3.3->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 3)) (2022.7)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from scikit-learn==1.7.2->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: scipy>=1.8.0 in /databricks/python3/lib/python3.10/site-packages (from scikit-learn==1.7.2->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 4)) (1.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (1.0.5)
# Requirement already satisfied: pillow>=8 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (23.2)
# Requirement already satisfied: pyparsing>=3 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: tenacity>=6.2.0 in /databricks/python3/lib/python3.10/site-packages (from plotly==5.24.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 7)) (8.1.0)
# Requirement already satisfied: Flask<4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.3.3)
# Requirement already satisfied: gunicorn<24 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (23.0.0)
# Requirement already satisfied: graphene<4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.4.3)
# Requirement already satisfied: mlflow-skinny==3.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.0.1)
# Requirement already satisfied: docker<8,>=4.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (7.1.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.0.44)
# Requirement already satisfied: alembic!=1.10.0,<2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.17.2)
# Requirement already satisfied: numba>=0.54 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (0.62.1)
# Requirement already satisfied: typing-extensions in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (4.15.0)
# Requirement already satisfied: cloudpickle in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (3.1.2)
# Requirement already satisfied: slicer==0.0.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (0.0.8)
# Requirement already satisfied: nvidia-nccl-cu12 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from xgboost==2.1.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 23)) (2.28.9)
# Requirement already satisfied: deprecation>=2.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.1.0)
# Requirement already satisfied: iterative-telemetry>=0.0.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.0.10)
# Requirement already satisfied: pydantic>=1.10.13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.12.4)
# Requirement already satisfied: urllib3>=1.26.19 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.26.20)
# Requirement already satisfied: certifi>=2024.7.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2025.11.12)
# Requirement already satisfied: cryptography>=43.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (46.0.3)
# Requirement already satisfied: ujson>=5.4.0 in /databricks/python3/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (5.4.0)
# Requirement already satisfied: rich>=13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (14.2.0)
# Requirement already satisfied: uuid6>=2024.7.10 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2025.0.1)
# Requirement already satisfied: fsspec>=2024.6.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2025.10.0)
# Requirement already satisfied: typing-inspect>=0.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.9.0)
# Requirement already satisfied: typer>=0.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.20.0)
# Requirement already satisfied: uvicorn[standard]>=0.22.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.38.0)
# Requirement already satisfied: requests>=2.32.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.32.5)
# Requirement already satisfied: statsmodels>=0.12.2 in /databricks/python3/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.13.5)
# Requirement already satisfied: nltk>=3.6.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.9.2)
# Requirement already satisfied: litestar>=2.8.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.18.0)
# Requirement already satisfied: watchdog>=3.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (6.0.0)
# Requirement already satisfied: dynaconf>=3.2.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.2.12)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil==2.9.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 30)) (1.16.0)
# Requirement already satisfied: click in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (8.3.1)
# Requirement already satisfied: entrypoints in /databricks/python3/lib/python3.10/site-packages (from papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (0.4)
# Requirement already satisfied: nbclient>=0.2.0 in /databricks/python3/lib/python3.10/site-packages (from papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (0.5.13)
# Requirement already satisfied: nbformat>=5.1.2 in /databricks/python3/lib/python3.10/site-packages (from papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (5.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.38.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.5.3)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.1.45)
# Requirement already satisfied: fastapi<1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.121.3)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.38.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (6.33.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.73.0)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /databricks/python3/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (5.3.2)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (8.7.0)
# Requirement already satisfied: Mako in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.3.10)
# Requirement already satisfied: tomli in /databricks/python3/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.0.1)
# Requirement already satisfied: cffi>=2.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from cryptography>=43.0.1->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.0.0)
# Requirement already satisfied: blinker>=1.6.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.9.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /databricks/python3/lib/python3.10/site-packages (from Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.1.2)
# Requirement already satisfied: Werkzeug>=2.3.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.2.0)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from graphene<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.2.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from graphene<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.2.7)
# Requirement already satisfied: filelock in /databricks/python3/lib/python3.10/site-packages (from iterative-telemetry>=0.0.5->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.16.1)
# Requirement already satisfied: distro in /usr/lib/python3/dist-packages (from iterative-telemetry>=0.0.5->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.7.0)
# Requirement already satisfied: appdirs in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from iterative-telemetry>=0.0.5->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.4.4)
# Requirement already satisfied: litestar-htmx>=0.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.5.0)
# Requirement already satisfied: anyio>=3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (4.11.0)
# Requirement already satisfied: multidict>=6.0.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (6.7.0)
# Requirement already satisfied: httpx>=0.22 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.28.1)
# Requirement already satisfied: polyfactory>=2.6.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.0.0)
# Requirement already satisfied: msgspec>=0.18.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.19.0)
# Requirement already satisfied: multipart>=1.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.3.0)
# Requirement already satisfied: rich-click in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.9.4)
# Requirement already satisfied: exceptiongroup in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.3.0)
# Requirement already satisfied: traitlets>=5.0.0 in /databricks/python3/lib/python3.10/site-packages (from nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (5.7.1)
# Requirement already satisfied: nest-asyncio in /databricks/python3/lib/python3.10/site-packages (from nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (1.5.6)
# Requirement already satisfied: jupyter-client>=6.1.5 in /databricks/python3/lib/python3.10/site-packages (from nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (7.3.4)
# Requirement already satisfied: fastjsonschema in /databricks/python3/lib/python3.10/site-packages (from nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /databricks/python3/lib/python3.10/site-packages (from nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (4.17.3)
# Requirement already satisfied: jupyter-core in /databricks/python3/lib/python3.10/site-packages (from nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (5.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from nltk>=3.6.7->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2025.11.3)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from numba>=0.54->shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (0.45.1)
# Requirement already satisfied: pydantic-core==2.41.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from pydantic>=1.10.13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from pydantic>=1.10.13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from pydantic>=1.10.13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.32.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.32.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from rich>=13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from rich>=13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (4.0.0)
# Requirement already satisfied: greenlet>=1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.2.4)
# Requirement already satisfied: patsy>=0.5.2 in /databricks/python3/lib/python3.10/site-packages (from statsmodels>=0.12.2->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.5.3)
# Requirement already satisfied: shellingham>=1.3.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from typer>=0.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /databricks/python3/lib/python3.10/site-packages (from typing-inspect>=0.9.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.4.3)
# Requirement already satisfied: h11>=0.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.16.0)
# Requirement already satisfied: uvloop>=0.15.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.22.1)
# Requirement already satisfied: httptools>=0.6.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.7.1)
# Requirement already satisfied: websockets>=10.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (15.0.1)
# Requirement already satisfied: python-dotenv>=0.13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.2.1)
# Requirement already satisfied: watchfiles>=0.13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.1.1)
# Requirement already satisfied: sniffio>=1.1 in /databricks/python3/lib/python3.10/site-packages (from anyio>=3->litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.2.0)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=43.0.1->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.21)
# Requirement already satisfied: google-auth~=2.0 in /databricks/python3/lib/python3.10/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.28.1)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (4.0.12)
# Requirement already satisfied: httpcore==1.* in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from httpx>=0.22->litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.0.9)
# Requirement already satisfied: zipp>=3.20 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.10/site-packages (from Jinja2>=3.1.2->Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /databricks/python3/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /databricks/python3/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (0.18.0)
# Requirement already satisfied: pyzmq>=23.0 in /databricks/python3/lib/python3.10/site-packages (from jupyter-client>=6.1.5->nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (23.2.0)
# Requirement already satisfied: tornado>=6.0 in /databricks/python3/lib/python3.10/site-packages (from jupyter-client>=6.1.5->nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (6.1)
# Requirement already satisfied: platformdirs>=2.5 in /databricks/python3/lib/python3.10/site-packages (from jupyter-core->nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (2.5.2)
# Requirement already satisfied: mdurl~=0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.1.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.59b0)
# Requirement already satisfied: faker>=5.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from polyfactory>=2.6.3->litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (38.2.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2b947b29-4210-478e-9ad4-a7b5294174e0/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /databricks/python3/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /databricks/python3/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (4.9)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /databricks/python3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.5.1)
# Installing collected packages: pyarrow, mlflow
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 22.0.0
#     Uninstalling pyarrow-22.0.0:
#       Successfully uninstalled pyarrow-22.0.0
#   Attempting uninstall: mlflow
#     Found existing installation: mlflow 3.6.0
#     Uninstalling mlflow-3.6.0:
#       Successfully uninstalled mlflow-3.6.0
# Successfully installed mlflow-3.0.1 pyarrow-20.0.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import sys
import os
import logging
sys.path.append(os.path.abspath('../'))

from utils.common_utils import (load_config, setup_logging, get_spark_session,
                                print_section_header, Timer, get_feature_store_client)
from utils.data_loader import load_all_tables, save_data_to_destination
from utils.feature_engineering import *

# %%
config = load_config('../config/config.yaml')
setup_logging(config)

print_section_header("Feature Engineering")
# Out:
# ================================================================================
#                               Feature Engineering
# ================================================================================

# %% [markdown]
# ## 1. Load Data

# %%
spark = None
if config['data_source']['type'] == 'unity_catalog':
    spark = get_spark_session(config)

# Fix paths to use absolute path relative to project root
if config['data_source']['type'] == 'csv':
    original_input_path = config['data_source']['csv']['input_path']
    config['data_source']['csv']['input_path'] = os.path.abspath('../data/raw')
    print(f"📂 Loading data from: {config['data_source']['csv']['input_path']}")

with Timer("Loading Data"):
    tables = load_all_tables(config, spark)

# Restore original path
if config['data_source']['type'] == 'csv':
    config['data_source']['csv']['input_path'] = original_input_path

print(f"\n✅ Loaded {len([t for t in tables.values() if t is not None])} tables")
# Out:
# ✅ Loaded 6 tables

# %%
# Create a wrapper function to handle optional address_df and column name conversion
from utils.feature_engineering import create_customer_demographic_features as _original_create_customer_demographic_features
import pandas as pd

def create_customer_demographic_features_wrapper(party_df, customer_df, address_df, reference_date):
    """
    Wrapper that handles optional address_df parameter and converts column names to uppercase.
    """
    # Convert column names to uppercase for consistency
    party_df = party_df.copy()
    party_df.columns = party_df.columns.str.upper()
    
    customer_df = customer_df.copy()
    customer_df.columns = customer_df.columns.str.upper()
    
    if address_df is not None:
        address_df = address_df.copy()
        address_df.columns = address_df.columns.str.upper()
    
    # Merge customer with party
    df = customer_df.merge(party_df, on='PARTYID', how='left')
    
    # Merge with address if provided
    if address_df is not None:
        df = df.merge(address_df, left_on='PRIMARYADDRESSID', right_on='ADDRESSID', how='left')
    
    # Calculate age
    ref_date = pd.to_datetime(reference_date)
    df['DATEOFBIRTH'] = pd.to_datetime(df['DATEOFBIRTH'])
    df['AGE'] = (ref_date - df['DATEOFBIRTH']).dt.days / 365.25
    
    # Convert AGE to integer
    df['AGE'] = df['AGE'].round().astype('Int64')  # Use Int64 to handle NaN values
    
    # Calculate customer tenure (in days)
    df['CUSTOMERESTABLISHEDDATE'] = pd.to_datetime(df['CUSTOMERESTABLISHEDDATE'])
    df['CUSTOMER_TENURE_DAYS'] = (ref_date - df['CUSTOMERESTABLISHEDDATE']).dt.days
    
    # Age group
    df['AGE_GROUP'] = pd.cut(df['AGE'], 
                             bins=[0, 25, 35, 45, 55, 65, 100],
                             labels=['18-25', '26-35', '36-45', '46-55', '56-65', '65+'])
    
    # Tenure group
    df['TENURE_GROUP'] = pd.cut(df['CUSTOMER_TENURE_DAYS'],
                                bins=[-1, 180, 365, 730, 1825, 999999],
                                labels=['0-6M', '6M-1Y', '1-2Y', '2-5Y', '5Y+'])
    
    # Select relevant features (exclude address columns if not available)
    feature_cols = ['CUSTOMERID', 'PARTYID', 'AGE', 'CUSTOMER_TENURE_DAYS',
                    'AGE_GROUP', 'TENURE_GROUP']
    
    # Add address columns only if address_df was provided
    if address_df is not None and 'CITY' in df.columns:
        feature_cols.extend(['CITY', 'STATE', 'POSTALCODE'])
    
    features = df[feature_cols].copy()
    
    logging.info(f"Created {len(feature_cols)} demographic features for {len(features)} customers")
    
    return features

# Override the function name for use in subsequent cells
create_customer_demographic_features = create_customer_demographic_features_wrapper

print("✅ Wrapper function created for demographic features with column name conversion")
# Out:
# ✅ Wrapper function created for demographic features with column name conversion

# %%
# Create wrapper functions for account and transaction features
from utils.feature_engineering import (
    create_account_features as _original_create_account_features,
    create_transaction_features as _original_create_transaction_features
)

def create_account_features_wrapper(customer_account_df, product_df, channel_df, reference_date):
    """
    Wrapper that converts column names to uppercase before processing.
    """
    # Convert column names to uppercase
    customer_account_df = customer_account_df.copy()
    customer_account_df.columns = customer_account_df.columns.str.upper()
    
    # Convert ORIGINATIONDATE from Unix timestamp to datetime if needed
    if customer_account_df['ORIGINATIONDATE'].dtype in ['int32', 'int64']:
        customer_account_df['ORIGINATIONDATE'] = pd.to_datetime(customer_account_df['ORIGINATIONDATE'], unit='s')
    
    product_df = product_df.copy()
    product_df.columns = product_df.columns.str.upper()
    
    channel_df = channel_df.copy()
    channel_df.columns = channel_df.columns.str.upper()
    
    # Call original function
    return _original_create_account_features(customer_account_df, product_df, channel_df, reference_date)

def create_transaction_features_wrapper(transaction_df, customer_account_df, reference_date, lookback_periods):
    """
    Wrapper that converts column names to uppercase before processing.
    """
    # Convert column names to uppercase
    transaction_df = transaction_df.copy()
    transaction_df.columns = transaction_df.columns.str.upper()
    
    customer_account_df = customer_account_df.copy()
    customer_account_df.columns = customer_account_df.columns.str.upper()
    
    # Call original function
    return _original_create_transaction_features(transaction_df, customer_account_df, reference_date, lookback_periods)

# Override the function names
create_account_features = create_account_features_wrapper
create_transaction_features = create_transaction_features_wrapper

print("✅ Wrapper functions created for account and transaction features")
# Out:
# ✅ Wrapper functions created for account and transaction features

# %% [markdown]
# ## 2. Create Features

# %%
reference_date = config['feature_engineering']['reference_date']
lookback_periods = config['feature_engineering']['lookback_periods']

# Demographic features (excluding address data)
demo_features = create_customer_demographic_features(
    tables['party'], tables['customer'], None, reference_date
)

# Account features
account_features = create_account_features(
    tables['customer_account'], tables['banking_product'], tables['channel'], reference_date
)

# Transaction features
transaction_features = create_transaction_features(
    tables['transaction'], tables['customer_account'], reference_date, lookback_periods
)

print("✅ Feature creation completed (excluding communication and document features)")
# Out:
# ✅ Feature creation completed (excluding communication and document features)

# %% [markdown]
# ## 3. Merge All Features

# %%
# Merge only demographic, account, and transaction features
all_features = merge_all_features([
    demo_features, account_features, transaction_features
])

# Handle missing values
all_features = handle_missing_values(
    all_features,
    config['feature_engineering']['missing_value_strategy']['numeric'],
    config['feature_engineering']['missing_value_strategy']['categorical']
)

print(f"\n✅ Final feature set: {len(all_features)} customers, {len(all_features.columns)} features")
# Out:
# ✅ Final feature set: 1000 customers, 43 features
# /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/utils/feature_engineering.py:401: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].fillna(mode_val[0])

# %% [markdown]
# ## 4. Create Target Variable

# %%
# Ensure latest version of feature_engineering (handles notebook re-runs after file edits)
import importlib, inspect
try:
    import utils.feature_engineering as fe
    importlib.reload(fe)
    from utils.feature_engineering import create_target_variable
    logging.info("Reloaded utils.feature_engineering module successfully")
except Exception as e:
    logging.warning(f"Could not reload feature_engineering module: {e}")

# Convert column names to uppercase and handle ORIGINATIONDATE
customer_account_upper = tables['customer_account'].copy()
customer_account_upper.columns = customer_account_upper.columns.str.upper()

# Convert ORIGINATIONDATE from Unix timestamp to datetime
if customer_account_upper['ORIGINATIONDATE'].dtype in ['int32', 'int64']:
    customer_account_upper['ORIGINATIONDATE'] = pd.to_datetime(customer_account_upper['ORIGINATIONDATE'], unit='s')

# Safely inspect signature to determine if training_ratio is supported
supports_training_ratio = False
try:
    sig = inspect.signature(create_target_variable)
    supports_training_ratio = 'training_ratio' in sig.parameters
    logging.info(f"create_target_variable signature: {sig}")
except Exception as e:
    logging.warning(f"Could not inspect create_target_variable signature: {e}")

if supports_training_ratio:
    target_df = create_target_variable(
        customer_account_upper,
        reference_date,
        prediction_window_days=365,
        training_ratio=config['feature_engineering']['training_data_ratio']
    )
else:
    logging.warning("training_ratio parameter not found; falling back to legacy call without sampling control")
    target_df = create_target_variable(
        customer_account_upper,
        reference_date,
        prediction_window_days=90
    )

logging.info(f"Target variable created for {len(target_df)} customers")
# Out:
# WARNING:root:Only 284 customers have next purchases, but target is 373
# WARNING:root:Using all 284 customers with purchases

# %% [markdown]
# ## 5. Save Features

# %%
# Install Databricks Feature Engineering package
# %pip install databricks-feature-engineering --quiet

print("✅ databricks-feature-engineering installed")
print("⚠️ Note: Restart Python manually if needed: dbutils.library.restartPython()")
# Out:
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# ✅ databricks-feature-engineering installed
# ⚠️ Note: Restart Python manually if needed: dbutils.library.restartPython()

# %%
# Save features and targets to Unity Catalog
print("💾 Saving features and targets...")

save_data_to_destination(all_features, config, 'customer_features', spark)
print("✅ Features saved")

save_data_to_destination(target_df, config, 'customer_targets', spark)
print("✅ Targets saved")

# Register to Databricks Feature Store
if config['data_source']['type'] == 'unity_catalog' and spark:
    try:
        from databricks.feature_engineering import FeatureEngineeringClient
        
        fe = FeatureEngineeringClient()
        
        catalog = config['data_source']['unity_catalog']['catalog']
        output_schema = config['data_source']['unity_catalog']['output_schema']
        feature_store_table = f"{catalog}.{output_schema}.customer_features_fs"
        
        print(f"\n📊 Feature Store: {feature_store_table}")
        
        # Check if table exists
        try:
            existing = spark.table(feature_store_table)
            print(f"  ✅ Feature table already exists")
            print(f"  Rows: {existing.count()}")
        except:
            # Create new feature table
            print(f"  Creating new feature table...")
            features_spark_df = spark.createDataFrame(all_features)
            
            fe.create_table(
                name=feature_store_table,
                primary_keys=['CUSTOMERID'],
                df=features_spark_df,
                description="Customer features for next best product recommendation"
            )
            print(f"  ✅ Feature table created")
        
        print(f"\n✅ Feature Store ready!")
        print(f"   Table: {feature_store_table}")
        print(f"   Primary Key: CUSTOMERID")
        print(f"   Features: {len(all_features.columns)} columns")
        print(f"   Rows: {len(all_features)} customers")
        
    except ImportError:
        print(f"\n⚠️ databricks-feature-engineering not installed")
        print(f"   Run cell 14.5 to install the package")
    except Exception as e:
        print(f"\n⚠️ Feature Store error: {str(e)}")
        print(f"   Features are still saved to Unity Catalog tables")
else:
    print("\n⚠️ Feature Store only available for Unity Catalog")

print("\n✅ Feature engineering completed!")
# Out:
# 💾 Saving features and targets...
# ✅ Features saved
# ✅ Targets saved
#
# 📊 Feature Store: datafabric_catalog.ml_outputs.customer_features_fs
#   ✅ Feature table already exists
#   Rows: 1000
#
# ✅ Feature Store ready!
#    Table: datafabric_catalog.ml_outputs.customer_features_fs
#    Primary Key: CUSTOMERID
#    Features: 43 columns
#    Rows: 1000 customers
#
# ✅ Feature engineering completed!
