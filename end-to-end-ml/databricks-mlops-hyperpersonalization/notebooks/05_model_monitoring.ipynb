# %%
# Install Databricks Feature Engineering for Feature Store
# %pip install databricks-feature-engineering --quiet

# Install project requirements
# !pip install -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt

dbutils.library.restartPython()
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlflow 3.6.0 requires mlflow-skinny==3.6.0, but you have mlflow-skinny 3.0.1 which is incompatible.
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: numpy==1.26.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: pandas==2.3.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 3)) (2.3.3)
# Requirement already satisfied: scikit-learn==1.7.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 4)) (1.7.2)
# Requirement already satisfied: matplotlib==3.10.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (3.10.7)
# Requirement already satisfied: seaborn==0.13.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 6)) (0.13.2)
# Requirement already satisfied: plotly==5.24.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 7)) (5.24.1)
# Requirement already satisfied: pyyaml==6.0.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 8)) (6.0.3)
# Collecting pyarrow==20.0.0 (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 9))
#   Downloading pyarrow-20.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting mlflow==3.0.1 (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17))
#   Downloading mlflow-3.0.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: shap==0.49.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (0.49.1)
# Requirement already satisfied: xgboost==2.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 23)) (2.1.0)
# Requirement already satisfied: evidently==0.6.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.6.1)
# Requirement already satisfied: python-dateutil==2.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 30)) (2.9.0)
# Requirement already satisfied: tqdm==4.67.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 31)) (4.67.1)
# Requirement already satisfied: joblib==1.5.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 32)) (1.5.2)
# Requirement already satisfied: papermill==2.5.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (2.5.0)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.10/site-packages (from pandas==2.3.3->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 3)) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from pandas==2.3.3->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in /databricks/python3/lib/python3.10/site-packages (from scikit-learn==1.7.2->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 4)) (1.10.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from scikit-learn==1.7.2->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (23.2)
# Requirement already satisfied: pillow>=8 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (9.4.0)
# Requirement already satisfied: pyparsing>=3 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /databricks/python3/lib/python3.10/site-packages (from plotly==5.24.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 7)) (8.1.0)
# Requirement already satisfied: mlflow-skinny==3.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.0.1)
# Requirement already satisfied: Flask<4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.3.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.17.2)
# Requirement already satisfied: docker<8,>=4.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (7.1.0)
# Requirement already satisfied: graphene<4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (23.0.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.0.44)
# Requirement already satisfied: slicer==0.0.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (0.62.1)
# Requirement already satisfied: cloudpickle in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (3.1.2)
# Requirement already satisfied: typing-extensions in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (4.15.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from xgboost==2.1.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 23)) (2.28.9)
# Requirement already satisfied: statsmodels>=0.12.2 in /databricks/python3/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.13.5)
# Requirement already satisfied: nltk>=3.6.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.9.2)
# Requirement already satisfied: requests>=2.32.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.32.5)
# Requirement already satisfied: pydantic>=1.10.13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.12.4)
# Requirement already satisfied: litestar>=2.8.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.18.0)
# Requirement already satisfied: typing-inspect>=0.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.9.0)
# Requirement already satisfied: uvicorn>=0.22.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.38.0)
# Requirement already satisfied: watchdog>=3.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (6.0.0)
# Requirement already satisfied: typer>=0.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.20.0)
# Requirement already satisfied: rich>=13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (14.2.0)
# Requirement already satisfied: iterative-telemetry>=0.0.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.0.10)
# Requirement already satisfied: dynaconf>=3.2.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.2.12)
# Requirement already satisfied: certifi>=2024.7.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2025.11.12)
# Requirement already satisfied: urllib3>=1.26.19 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.26.20)
# Requirement already satisfied: fsspec>=2024.6.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2025.10.0)
# Requirement already satisfied: ujson>=5.4.0 in /databricks/python3/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (5.4.0)
# Requirement already satisfied: deprecation>=2.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.1.0)
# Requirement already satisfied: uuid6>=2024.7.10 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2025.0.1)
# Requirement already satisfied: cryptography>=43.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (46.0.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil==2.9.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 30)) (1.16.0)
# Requirement already satisfied: click in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (8.3.1)
# Requirement already satisfied: nbformat>=5.1.2 in /databricks/python3/lib/python3.10/site-packages (from papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (5.7.0)
# Requirement already satisfied: nbclient>=0.2.0 in /databricks/python3/lib/python3.10/site-packages (from papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (0.5.13)
# Requirement already satisfied: entrypoints in /databricks/python3/lib/python3.10/site-packages (from papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (0.4)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /databricks/python3/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (5.3.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.73.0)
# Requirement already satisfied: fastapi<1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.121.3)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.38.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (6.33.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.5.3)
# Requirement already satisfied: Mako in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.3.10)
# Requirement already satisfied: tomli in /databricks/python3/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.0.1)
# Requirement already satisfied: google-auth~=2.0 in /databricks/python3/lib/python3.10/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.28.1)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.0.4)
# Requirement already satisfied: Werkzeug>=2.3.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /databricks/python3/lib/python3.10/site-packages (from Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /databricks/python3/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /databricks/python3/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (4.9)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from graphene<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from graphene<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.2.0)
# Requirement already satisfied: zipp>=3.20 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.59b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from pydantic>=1.10.13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from pydantic>=1.10.13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from pydantic>=1.10.13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.32.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.32.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.4)
# Requirement already satisfied: pyasn1>=0.1.3 in /databricks/python3/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.5.1)
# Requirement already satisfied: greenlet>=1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.2.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (4.11.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /databricks/python3/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.2.0)
# Requirement already satisfied: h11>=0.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from uvicorn>=0.22.0->uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.16.0)
# Requirement already satisfied: cffi>=2.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from cryptography>=43.0.1->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.0.0)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=43.0.1->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.21)
# Requirement already satisfied: appdirs in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from iterative-telemetry>=0.0.5->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.4.4)
# Requirement already satisfied: filelock in /databricks/python3/lib/python3.10/site-packages (from iterative-telemetry>=0.0.5->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.16.1)
# Requirement already satisfied: distro in /usr/lib/python3/dist-packages (from iterative-telemetry>=0.0.5->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.10/site-packages (from Jinja2>=3.1.2->Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.1.1)
# Requirement already satisfied: httpx>=0.22 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.28.1)
# Requirement already satisfied: litestar-htmx>=0.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.5.0)
# Requirement already satisfied: msgspec>=0.18.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.19.0)
# Requirement already satisfied: multidict>=6.0.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (6.7.0)
# Requirement already satisfied: multipart>=1.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.3.0)
# Requirement already satisfied: polyfactory>=2.6.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.0.0)
# Requirement already satisfied: rich-click in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.9.4)
# Requirement already satisfied: httpcore==1.* in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from httpx>=0.22->litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.0.9)
# Requirement already satisfied: traitlets>=5.0.0 in /databricks/python3/lib/python3.10/site-packages (from nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (5.7.1)
# Requirement already satisfied: jupyter-client>=6.1.5 in /databricks/python3/lib/python3.10/site-packages (from nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (7.3.4)
# Requirement already satisfied: nest-asyncio in /databricks/python3/lib/python3.10/site-packages (from nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (1.5.6)
# Requirement already satisfied: jupyter-core>=4.9.2 in /databricks/python3/lib/python3.10/site-packages (from jupyter-client>=6.1.5->nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (5.2.0)
# Requirement already satisfied: pyzmq>=23.0 in /databricks/python3/lib/python3.10/site-packages (from jupyter-client>=6.1.5->nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (23.2.0)
# Requirement already satisfied: tornado>=6.0 in /databricks/python3/lib/python3.10/site-packages (from jupyter-client>=6.1.5->nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (6.1)
# Requirement already satisfied: platformdirs>=2.5 in /databricks/python3/lib/python3.10/site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.5->nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (2.5.2)
# Requirement already satisfied: fastjsonschema in /databricks/python3/lib/python3.10/site-packages (from nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /databricks/python3/lib/python3.10/site-packages (from nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (4.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /databricks/python3/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /databricks/python3/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (0.18.0)
# Requirement already satisfied: regex>=2021.8.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from nltk>=3.6.7->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2025.11.3)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from numba>=0.54->shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (0.45.1)
# Requirement already satisfied: faker>=5.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from polyfactory>=2.6.3->litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (38.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from rich>=13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from rich>=13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.1.2)
# Requirement already satisfied: patsy>=0.5.2 in /databricks/python3/lib/python3.10/site-packages (from statsmodels>=0.12.2->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.5.3)
# Requirement already satisfied: shellingham>=1.3.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from typer>=0.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /databricks/python3/lib/python3.10/site-packages (from typing-inspect>=0.9.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.4.3)
# Requirement already satisfied: httptools>=0.6.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.2.1)
# Requirement already satisfied: uvloop>=0.15.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (15.0.1)
# Downloading pyarrow-20.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (42.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/42.3 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 42.2/42.3 MB 369.1 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 MB 210.7 MB/s  0:00:00
# Downloading mlflow-3.0.1-py3-none-any.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/24.6 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 131.4 MB/s  0:00:00
# Installing collected packages: pyarrow, mlflow
#
#   Attempting uninstall: pyarrow
#
#     Found existing installation: pyarrow 22.0.0
#
#     Uninstalling pyarrow-22.0.0:
#
#       Successfully uninstalled pyarrow-22.0.0
#
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/2 [pyarrow]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/2 [pyarrow]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/2 [pyarrow]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/2 [pyarrow]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/2 [pyarrow]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/2 [pyarrow]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/2 [pyarrow]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/2 [pyarrow]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/2 [pyarrow]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/2 [pyarrow]
#   Attempting uninstall: mlflow
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/2 [pyarrow]
#     Found existing installation: mlflow 3.6.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/2 [pyarrow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 1/2 [mlflow]
#     Uninstalling mlflow-3.6.0:
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 1/2 [mlflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 1/2 [mlflow]
#       Successfully uninstalled mlflow-3.6.0
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 1/2 [mlflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 1/2 [mlflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 1/2 [mlflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 1/2 [mlflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 1/2 [mlflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 1/2 [mlflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 1/2 [mlflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 1/2 [mlflow]
#    ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━ 1/2 [mlflow]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [mlflow]
#
# Successfully installed mlflow-3.0.1 pyarrow-20.0.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import sys
import os
import logging
import pandas as pd
sys.path.append(os.path.abspath('../'))

from utils.common_utils import load_config, setup_logging, get_spark_session, print_section_header, Timer
from utils.data_loader import load_data_from_source
from utils.model_monitoring import *

# %%
config = load_config('../config/config.yaml')
setup_logging(config)

print_section_header("Model Monitoring")
# Out:
# ================================================================================
#                                 Model Monitoring
# ================================================================================

# %% [markdown]
# ## 1. Load Reference and Current Data

# %%
spark = None
if config['data_source']['type'] == 'unity_catalog':
    spark = get_spark_session(config)

# Load reference (training) features, targets, and current predictions
if config['data_source']['type'] == 'unity_catalog':
    uc_config = config['data_source']['unity_catalog']
    catalog = uc_config['catalog']
    output_schema = uc_config['output_schema']
    
    # Define table names
    feature_store_table = f"{catalog}.{output_schema}.customer_features_fs"
    features_table = f"{catalog}.{output_schema}.customer_features"
    targets_table = f"{catalog}.{output_schema}.customer_targets"
    predictions_table = f"{catalog}.{output_schema}.product_recommendations"
    
    print(f"📊 Loading reference features from Feature Store: {feature_store_table}")
    print(f"📂 Loading targets from: {targets_table}")
    print(f"📂 Loading predictions from: {predictions_table}")
    
    # Try to load features from Feature Store first
    try:
        from databricks.feature_engineering import FeatureEngineeringClient
        
        fe = FeatureEngineeringClient()
        reference_features_spark = fe.read_table(name=feature_store_table)
        reference_features = reference_features_spark.toPandas()
        print(f"✅ Loaded reference features from Feature Store")
        
    except ImportError:
        print(f"⚠️ Feature Engineering client not available, using direct table read")
        reference_features = spark.table(features_table).toPandas()
        print(f"✅ Loaded reference features from Unity Catalog table")
    except Exception as e:
        print(f"⚠️ Error reading from Feature Store: {str(e)}")
        reference_features = spark.table(features_table).toPandas()
        print(f"✅ Loaded reference features from Unity Catalog table")
    
    # Load targets
    target_data = spark.table(targets_table).toPandas()
    
    # Load predictions
    try:
        current_predictions = spark.table(predictions_table).toPandas()
        print(f"✅ Loaded predictions from Unity Catalog")
    except Exception as e:
        print(f"⚠️ Could not load predictions table: {str(e)}")
        print(f"   Table may not exist yet. Run 05_batch_inference.ipynb first.")
        # Create dummy predictions for demo
        current_predictions = pd.DataFrame({
            'CUSTOMERID': reference_features['CUSTOMERID'].sample(100).values,
            'PREDICTED_PRODUCT_ID': [101, 102, 103] * 33 + [101]
        })
        print(f"⚠️ Using dummy predictions for demo purposes")
        
else:
    # CSV mode
    reference_path = os.path.abspath('../data/processed/customer_features.csv')
    target_path = os.path.abspath('../data/processed/customer_targets.csv')
    predictions_path = os.path.abspath('../outputs/predictions/product_recommendations.csv')
    
    print(f"📂 Loading reference features from: {reference_path}")
    print(f"📂 Loading target data from: {target_path}")
    print(f"📂 Loading predictions from: {predictions_path}")
    
    reference_features = pd.read_csv(reference_path)
    target_data = pd.read_csv(target_path)
    
    try:
        current_predictions = pd.read_csv(predictions_path)
    except FileNotFoundError:
        print(f"⚠️ Predictions file not found. Using dummy data for demo.")
        current_predictions = pd.DataFrame({
            'CUSTOMERID': reference_features['CUSTOMERID'].sample(100).values,
            'PREDICTED_PRODUCT_ID': [101, 102, 103] * 33 + [101]
        })

print(f"\n✅ Loaded reference features: {len(reference_features)} records")
print(f"✅ Loaded target data: {len(target_data)} records")
print(f"✅ Loaded current predictions: {len(current_predictions)} records")
# Out:
# 📊 Loading reference features from Feature Store: datafabric_catalog.ml_outputs.customer_features_fs
# 📂 Loading targets from: datafabric_catalog.ml_outputs.customer_targets
# 📂 Loading predictions from: datafabric_catalog.ml_outputs.product_recommendations
# ✅ Loaded reference features from Feature Store
# ✅ Loaded predictions from Unity Catalog
#
# ✅ Loaded reference features: 1000 records
# ✅ Loaded target data: 467 records
# ✅ Loaded current predictions: 2376 records

# %% [markdown]
# ## 2. Analyze Prediction Distribution

# %%
pred_distribution = calculate_prediction_distribution(current_predictions)

print(f"\nPrediction Distribution:")
print(f"  Total Predictions: {pred_distribution['total_predictions']}")
print(f"  Unique Products: {pred_distribution['unique_products']}")
print(f"  Entropy: {pred_distribution['entropy']:.4f}")
# Out:
# Prediction Distribution:
#   Total Predictions: 2376
#   Unique Products: 10
#   Entropy: 2.9897

# %% [markdown]
# ## 3. Detect Feature Drift

# %%
# For drift detection, we'd need current production data
# For demo, we'll use a sample
current_sample = reference_features.sample(n=min(1000, len(reference_features)), random_state=42)

drift_results = detect_feature_drift(
    reference_features.select_dtypes(include=['number']),
    current_sample.select_dtypes(include=['number']),
    threshold=config['monitoring']['drift_thresholds']['feature_drift']
)

print(f"\nDrift Detection:")
print(f"  Features Checked: {drift_results['total_features_checked']}")
print(f"  Drifted Features: {drift_results['drifted_features_count']}")

if drift_results['drifted_features']:
    print(f"  Drifted Features: {', '.join(drift_results['drifted_features'][:5])}")
# Out:
# /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/utils/model_monitoring.py:94: RuntimeWarning: invalid value encountered in scalar divide
#   'mean_change_pct': float((curr_values.mean() - ref_values.mean()) / ref_values.mean() * 100)
# Drift Detection:
#   Features Checked: 39
#   Drifted Features: 0

# %% [markdown]
# ## 4. Calculate Data Quality Metrics

# %%
data_quality = calculate_data_quality_metrics(current_sample)

print(f"\nData Quality:")
print(f"  Quality Score: {data_quality['quality_score']:.2f}")
print(f"  Missing Percentage: {data_quality['missing_percentage']:.2f}%")
print(f"  Duplicate Rows: {data_quality['duplicate_rows']}")
# Out:
# Data Quality:
#   Quality Score: 1.00
#   Missing Percentage: 0.00%
#   Duplicate Rows: 0

# %% [markdown]
# ## 5. Compare Model Performance

# %%
# Baseline metrics (from training)
baseline_metrics = {
    'accuracy': 0.75,
    'precision_weighted': 0.73,
    'recall_weighted': 0.75,
    'f1_weighted': 0.74
}

# Current metrics (simulated for demo)
current_metrics = {
    'accuracy': 0.72,
    'precision_weighted': 0.70,
    'recall_weighted': 0.72,
    'f1_weighted': 0.71
}

performance_comparison = compare_model_performance(
    current_metrics,
    baseline_metrics,
    threshold=config['monitoring']['drift_thresholds']['prediction_drift']
)

print(f"\nPerformance Comparison:")
print(f"  Degraded Metrics: {performance_comparison['degraded_metrics_count']}")

for metric in performance_comparison['metric_comparisons'].values():
    print(f"  {metric}")
# Out:
# Performance Comparison:
#   Degraded Metrics: 0
#   {'baseline': 0.75, 'current': 0.72, 'change': -0.030000000000000027, 'change_percentage': -4.0000000000000036, 'degraded': False}
#   {'baseline': 0.73, 'current': 0.7, 'change': -0.030000000000000027, 'change_percentage': -4.109589041095894, 'degraded': False}
#   {'baseline': 0.75, 'current': 0.72, 'change': -0.030000000000000027, 'change_percentage': -4.0000000000000036, 'degraded': False}
#   {'baseline': 0.74, 'current': 0.71, 'change': -0.030000000000000027, 'change_percentage': -4.054054054054058, 'degraded': False}

# %% [markdown]
# ## 6. Generate Monitoring Report

# %%
report_df = generate_monitoring_report(
    pred_distribution,
    drift_results,
    data_quality,
    performance_comparison,
    config
)

print("\nMonitoring Report:")
print(report_df.to_string(index=False))
# Out:
# Monitoring Report:
#       monitoring_timestamp overall_status alerts  prediction_entropy  unique_products_predicted  total_predictions  drifted_features_count  data_quality_score  missing_percentage  degraded_metrics_count
# 2025-11-21 06:49:58.935603        HEALTHY   None            2.989731                         10               2376                       0                 1.0                 0.0                       0

# %% [markdown]
# ## 7. Save Monitoring Results

# %%
detailed_results = {
    'prediction_distribution': pred_distribution,
    'drift_results': drift_results,
    'data_quality': data_quality,
    'performance_comparison': performance_comparison
}

save_monitoring_results(report_df, detailed_results, config)

print("\n✅ Monitoring results saved (CSV, JSON, HTML)!")
# Out:
# ✅ Monitoring results saved (CSV, JSON, HTML)!

# %% [markdown]
# ## 9. Monitoring Summary

# %% [markdown]
# ## 8. Generate Evidently Reports
#
# Generate an HTML report using Evidently's DataDriftPreset to check feature drift between reference (training) and current data.
#
# The report is saved to the configured monitoring output directory with a timestamped filename.

# %%
# Generate Evidently HTML report for Data Drift
print("\n🔬 Generating Evidently Data Drift report...")

import datetime
from pathlib import Path
import os
import pandas as pd
import numpy as np

try:
    from evidently.report import Report
    from evidently.metric_preset import DataDriftPreset
    import evidently
    ev_version = getattr(evidently, '__version__', 'unknown')
    print(f"✅ Using Evidently version: {ev_version}")
except ImportError as e:
    print(f"❌ Evidently not available: {str(e)}")
    print("\n⚠️ Evidently was installed in cell 1. Please:")
    print("   1. Restart Python: dbutils.library.restartPython()")
    print("   2. Rerun cells 2-20")
    raise ImportError("Evidently not available. Python restart may be needed.")

# Prepare output directory
output_dir = config['monitoring']['output_path']
if not os.path.isabs(output_dir):
    output_dir = os.path.abspath(os.path.join('..', output_dir))
Path(output_dir).mkdir(parents=True, exist_ok=True)

# Timestamp for file names
ts = datetime.datetime.utcnow().strftime('%Y%m%d_%H%M%S')

# Build reference and current DataFrames
reference_df = reference_features.copy()
current_df = current_sample.copy()

# Convert all object columns to numeric (fix Decimal serialization)
print("\n🔧 Preparing data for Evidently...")
for col in reference_df.select_dtypes(include=['object']).columns:
    try:
        # Try to convert to numeric
        reference_df[col] = pd.to_numeric(reference_df[col], errors='coerce')
        current_df[col] = pd.to_numeric(current_df[col], errors='coerce')
        print(f"   • Converted {col} to numeric")
    except:
        pass

# Identifier-like columns to drop for drift analysis
id_like_cols = [c for c in reference_df.columns if c.lower() in {"customerid", "customer_id", "id", "partyid"}]

# Prepare feature-only DataFrames for drift detection (exclude ID columns)
ref_features_only = reference_df.drop(columns=id_like_cols, errors='ignore')
curr_features_only = current_df.drop(columns=id_like_cols, errors='ignore')

# Drop columns that are all NaN (empty after conversion)
empty_cols = []
for col in ref_features_only.columns:
    if ref_features_only[col].isna().all() or curr_features_only[col].isna().all():
        empty_cols.append(col)

if empty_cols:
    print(f"   • Dropping {len(empty_cols)} empty columns: {', '.join(empty_cols)}")
    ref_features_only = ref_features_only.drop(columns=empty_cols)
    curr_features_only = curr_features_only.drop(columns=empty_cols)

print(f"\n📊 Analyzing drift between:")
print(f"   Reference: {len(ref_features_only)} rows, {len(ref_features_only.columns)} features")
print(f"   Current: {len(curr_features_only)} rows, {len(curr_features_only.columns)} features")

# Generate Data Drift Report
print("\n   • Generating DataDriftPreset report...")
data_drift_report = Report(metrics=[DataDriftPreset()])
data_drift_path = os.path.join(output_dir, f"evidently_data_drift_{ts}.html")

try:
    data_drift_report.run(reference_data=ref_features_only, current_data=curr_features_only)
    data_drift_report.save_html(data_drift_path)
    print(f"     ✅ Saved: {os.path.basename(data_drift_path)}")
    print(f"\n✅ Evidently Data Drift report generation complete.")
    print(f"📊 Report saved to: {data_drift_path}")
except Exception as ex:
    print(f"     ⚠️ Failed to generate report: {str(ex)}")
    print(f"     Continuing without Evidently report...")
# Out:
# 🔬 Generating Evidently Data Drift report...
# ✅ Using Evidently version: 0.6.1
#
# 🔧 Preparing data for Evidently...
#    • Converted AGE_GROUP to numeric
#    • Converted TENURE_GROUP to numeric
#    • Converted MIN_INTEREST_RATE to numeric
#    • Converted MAX_INTEREST_RATE to numeric
#    • Dropping 2 empty columns: AGE_GROUP, TENURE_GROUP
#
# 📊 Analyzing drift between:
#    Reference: 1000 rows, 39 features
#    Current: 1000 rows, 39 features
#
#    • Generating DataDriftPreset report...
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-2bf5b1d0-779e-48d1-87da-33660b58090a/lib/python3.10/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
#      ✅ Saved: evidently_data_drift_20251121_065001.html
#
# ✅ Evidently Data Drift report generation complete.
# 📊 Report saved to: /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/outputs/monitoring/evidently_data_drift_20251121_065001.html

# %%
print_section_header("Monitoring Summary")

status = report_df['overall_status'].values[0]
alerts = report_df['alerts'].values[0]

# Resolve absolute monitoring output path
import os
monitoring_path = config['monitoring']['output_path']
if not os.path.isabs(monitoring_path):
    workspace_root = os.path.abspath('..')
    monitoring_path = os.path.join(workspace_root, monitoring_path.lstrip('./'))

print(f"""
Overall Status: {status}
Alerts: {alerts}

Key Metrics:
- Prediction Entropy: {pred_distribution['entropy']:.4f}
- Drifted Features: {drift_results['drifted_features_count']}
- Data Quality Score: {data_quality['quality_score']:.2f}
- Degraded Metrics: {performance_comparison['degraded_metrics_count']}

📁 Monitoring outputs saved to: {monitoring_path}

📊 Reports Generated:
   ✓ monitoring_report_<timestamp>.csv - Summary metrics table
   ✓ monitoring_details_<timestamp>.json - Detailed results
   ✓ monitoring_report_<timestamp>.html - Interactive HTML dashboard
   ✓ evidently_data_drift_<timestamp>.html - Data Drift analysis report

💡 Open the HTML files in a browser for interactive visualizations!

✅ Model monitoring completed!
""")
# Out:
# ================================================================================
#                                Monitoring Summary
# ================================================================================
#
#
# Overall Status: HEALTHY
# Alerts: None
#
# Key Metrics:
# - Prediction Entropy: 2.9897
# - Drifted Features: 0
# - Data Quality Score: 1.00
# - Degraded Metrics: 0
#
# 📁 Monitoring outputs saved to: /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/outputs/monitoring
#
# 📊 Reports Generated:
#    ✓ monitoring_report_<timestamp>.csv - Summary metrics table
#    ✓ monitoring_details_<timestamp>.json - Detailed results
#    ✓ monitoring_report_<timestamp>.html - Interactive HTML dashboard
#    ✓ evidently_data_drift_<timestamp>.html - Data Drift analysis report
#
# 💡 Open the HTML files in a browser for interactive visualizations!
#
# ✅ Model monitoring completed!
