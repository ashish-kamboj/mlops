# %%
# Install dependencies
# !pip install -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt

# Install Databricks Feature Engineering for Feature Store support
# %pip install databricks-feature-engineering --quiet

print("✅ All dependencies installed")
# Out:
# Requirement already satisfied: numpy==1.26.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: pandas==2.3.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 3)) (2.3.3)
# Requirement already satisfied: scikit-learn==1.7.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 4)) (1.7.2)
# Requirement already satisfied: matplotlib==3.10.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (3.10.7)
# Requirement already satisfied: seaborn==0.13.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 6)) (0.13.2)
# Requirement already satisfied: plotly==5.24.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 7)) (5.24.1)
# Requirement already satisfied: pyyaml==6.0.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 8)) (6.0.3)
# Requirement already satisfied: pyarrow==20.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 9)) (20.0.0)
# Requirement already satisfied: mlflow==3.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.0.1)
# Requirement already satisfied: shap==0.49.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (0.49.1)
# Requirement already satisfied: xgboost==2.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 23)) (2.1.0)
# Requirement already satisfied: evidently==0.6.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.6.1)
# Requirement already satisfied: python-dateutil==2.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 30)) (2.9.0)
# Requirement already satisfied: tqdm==4.67.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 31)) (4.67.1)
# Requirement already satisfied: joblib==1.5.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 32)) (1.5.2)
# Requirement already satisfied: papermill==2.5.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (2.5.0)
# Requirement already satisfied: tzdata>=2022.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from pandas==2.3.3->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.10/site-packages (from pandas==2.3.3->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 3)) (2022.7)
# Requirement already satisfied: scipy>=1.8.0 in /databricks/python3/lib/python3.10/site-packages (from scikit-learn==1.7.2->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 4)) (1.10.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from scikit-learn==1.7.2->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (23.2)
# Requirement already satisfied: pyparsing>=3 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (4.25.0)
# Requirement already satisfied: pillow>=8 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (9.4.0)
# Requirement already satisfied: tenacity>=6.2.0 in /databricks/python3/lib/python3.10/site-packages (from plotly==5.24.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 7)) (8.1.0)
# Requirement already satisfied: mlflow-skinny==3.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.0.1)
# Requirement already satisfied: alembic!=1.10.0,<2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.17.2)
# Requirement already satisfied: gunicorn<24 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (23.0.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.0.44)
# Requirement already satisfied: Flask<4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.3.3)
# Requirement already satisfied: docker<8,>=4.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (7.1.0)
# Requirement already satisfied: graphene<4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.4.3)
# Requirement already satisfied: typing-extensions in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (4.15.0)
# Requirement already satisfied: numba>=0.54 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (0.62.1)
# Requirement already satisfied: slicer==0.0.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (0.0.8)
# Requirement already satisfied: cloudpickle in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (3.1.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from xgboost==2.1.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 23)) (2.28.9)
# Requirement already satisfied: cryptography>=43.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (46.0.3)
# Requirement already satisfied: requests>=2.32.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.32.5)
# Requirement already satisfied: litestar>=2.8.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.18.0)
# Requirement already satisfied: deprecation>=2.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.1.0)
# Requirement already satisfied: urllib3>=1.26.19 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.26.20)
# Requirement already satisfied: certifi>=2024.7.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2025.11.12)
# Requirement already satisfied: ujson>=5.4.0 in /databricks/python3/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (5.4.0)
# Requirement already satisfied: nltk>=3.6.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.9.2)
# Requirement already satisfied: fsspec>=2024.6.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2025.10.0)
# Requirement already satisfied: typing-inspect>=0.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.9.0)
# Requirement already satisfied: uvicorn[standard]>=0.22.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.38.0)
# Requirement already satisfied: watchdog>=3.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (6.0.0)
# Requirement already satisfied: pydantic>=1.10.13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.12.4)
# Requirement already satisfied: rich>=13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (14.2.0)
# Requirement already satisfied: statsmodels>=0.12.2 in /databricks/python3/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.13.5)
# Requirement already satisfied: typer>=0.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.20.0)
# Requirement already satisfied: dynaconf>=3.2.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.2.12)
# Requirement already satisfied: uuid6>=2024.7.10 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2025.0.1)
# Requirement already satisfied: iterative-telemetry>=0.0.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.0.10)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil==2.9.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 30)) (1.16.0)
# Requirement already satisfied: nbclient>=0.2.0 in /databricks/python3/lib/python3.10/site-packages (from papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (0.5.13)
# Requirement already satisfied: click in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (8.3.1)
# Requirement already satisfied: nbformat>=5.1.2 in /databricks/python3/lib/python3.10/site-packages (from papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (5.7.0)
# Requirement already satisfied: entrypoints in /databricks/python3/lib/python3.10/site-packages (from papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (0.4)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /databricks/python3/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (5.3.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (6.33.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.5.3)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (8.7.0)
# Requirement already satisfied: fastapi<1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.121.3)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.38.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.73.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.1.45)
# Requirement already satisfied: Mako in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.3.10)
# Requirement already satisfied: tomli in /databricks/python3/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.0.1)
# Requirement already satisfied: cffi>=2.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from cryptography>=43.0.1->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.0.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.9.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /databricks/python3/lib/python3.10/site-packages (from Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.1.2)
# Requirement already satisfied: Werkzeug>=2.3.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.1.3)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from graphene<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.2.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from graphene<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.2.7)
# Requirement already satisfied: filelock in /databricks/python3/lib/python3.10/site-packages (from iterative-telemetry>=0.0.5->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.16.1)
# Requirement already satisfied: appdirs in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from iterative-telemetry>=0.0.5->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.4.4)
# Requirement already satisfied: distro in /usr/lib/python3/dist-packages (from iterative-telemetry>=0.0.5->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.7.0)
# Requirement already satisfied: msgspec>=0.18.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.19.0)
# Requirement already satisfied: multidict>=6.0.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (6.7.0)
# Requirement already satisfied: multipart>=1.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.3.0)
# Requirement already satisfied: httpx>=0.22 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.28.1)
# Requirement already satisfied: litestar-htmx>=0.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.5.0)
# Requirement already satisfied: anyio>=3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (4.11.0)
# Requirement already satisfied: exceptiongroup in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.3.0)
# Requirement already satisfied: polyfactory>=2.6.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.0.0)
# Requirement already satisfied: rich-click in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.9.4)
# Requirement already satisfied: traitlets>=5.0.0 in /databricks/python3/lib/python3.10/site-packages (from nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (5.7.1)
# Requirement already satisfied: jupyter-client>=6.1.5 in /databricks/python3/lib/python3.10/site-packages (from nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (7.3.4)
# Requirement already satisfied: nest-asyncio in /databricks/python3/lib/python3.10/site-packages (from nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (1.5.6)
# Requirement already satisfied: jupyter-core in /databricks/python3/lib/python3.10/site-packages (from nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (5.2.0)
# Requirement already satisfied: jsonschema>=2.6 in /databricks/python3/lib/python3.10/site-packages (from nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (4.17.3)
# Requirement already satisfied: fastjsonschema in /databricks/python3/lib/python3.10/site-packages (from nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (2.20.0)
# Requirement already satisfied: regex>=2021.8.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from nltk>=3.6.7->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2025.11.3)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from numba>=0.54->shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (0.45.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from pydantic>=1.10.13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from pydantic>=1.10.13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from pydantic>=1.10.13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.32.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.32.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from rich>=13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from rich>=13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (4.0.0)
# Requirement already satisfied: greenlet>=1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.2.4)
# Requirement already satisfied: patsy>=0.5.2 in /databricks/python3/lib/python3.10/site-packages (from statsmodels>=0.12.2->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.5.3)
# Requirement already satisfied: shellingham>=1.3.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from typer>=0.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /databricks/python3/lib/python3.10/site-packages (from typing-inspect>=0.9.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.4.3)
# Requirement already satisfied: h11>=0.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.16.0)
# Requirement already satisfied: python-dotenv>=0.13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.2.1)
# Requirement already satisfied: websockets>=10.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (15.0.1)
# Requirement already satisfied: watchfiles>=0.13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.1.1)
# Requirement already satisfied: uvloop>=0.15.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.22.1)
# Requirement already satisfied: httptools>=0.6.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.7.1)
# Requirement already satisfied: sniffio>=1.1 in /databricks/python3/lib/python3.10/site-packages (from anyio>=3->litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.2.0)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=43.0.1->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.21)
# Requirement already satisfied: google-auth~=2.0 in /databricks/python3/lib/python3.10/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.28.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.0.4)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.50.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (4.0.12)
# Requirement already satisfied: httpcore==1.* in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from httpx>=0.22->litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.0.9)
# Requirement already satisfied: zipp>=3.20 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.10/site-packages (from Jinja2>=3.1.2->Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /databricks/python3/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /databricks/python3/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (22.1.0)
# Requirement already satisfied: tornado>=6.0 in /databricks/python3/lib/python3.10/site-packages (from jupyter-client>=6.1.5->nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (6.1)
# Requirement already satisfied: pyzmq>=23.0 in /databricks/python3/lib/python3.10/site-packages (from jupyter-client>=6.1.5->nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (23.2.0)
# Requirement already satisfied: platformdirs>=2.5 in /databricks/python3/lib/python3.10/site-packages (from jupyter-core->nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (2.5.2)
# Requirement already satisfied: mdurl~=0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.1.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.59b0)
# Requirement already satisfied: faker>=5.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from polyfactory>=2.6.3->litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (38.2.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (5.0.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /databricks/python3/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /databricks/python3/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /databricks/python3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.5.1)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# ✅ All dependencies installed

# %%
# Fix typing_extensions version issue
# The Sentinel class was added in typing_extensions 4.6.0
# %pip install --upgrade typing_extensions>=4.6.0 pydantic>=2.0.0 --quiet

# Restart Python kernel to use updated packages
dbutils.library.restartPython()
# Out:
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import sys
import os
import logging
import importlib

sys.path.append(os.path.abspath('../'))

from utils.common_utils import load_config, setup_logging, print_section_header, Timer, get_spark_session
from utils.data_loader import load_data_from_source
from utils import model_training
importlib.reload(model_training)
from utils.model_training import (
    prepare_training_data, get_model, train_model, evaluate_model,
    get_feature_importance, plot_feature_importance, log_model_to_mlflow
)
import mlflow
import pandas as pd
import numpy as np

# %%
# Override prepare_training_data to fix the bug and keep interest rates as numeric
from typing import Dict, Any, Tuple
import pandas as pd
import logging
from sklearn.model_selection import train_test_split

def prepare_training_data(features_df: pd.DataFrame,
                         target_df: pd.DataFrame,
                         config: Dict[str, Any]) -> Tuple[pd.DataFrame, pd.DataFrame, pd.Series, pd.Series]:
    """
    Prepare data for model training (train-test split).
    
    FIXED: 
    1. Interest rate columns are kept as numeric instead of one-hot encoded
    2. feature_cols is properly updated after one-hot encoding
    
    Args:
        features_df: DataFrame with features
        target_df: DataFrame with target variable
        config: Configuration dictionary
        
    Returns:
        Tuple of (X_train, X_test, y_train, y_test)
    """
    logging.info("Preparing training data...")
    
    # Merge features with target
    df = features_df.merge(target_df, on='CUSTOMERID', how='inner')
    
    # Remove customers without target (didn't purchase next product)
    df = df[df['NEXT_PRODUCT_ID'].notna()].copy()
    
    logging.info(f"Training dataset: {len(df)} samples with target")
    
    # Separate features and target
    target_col = config['model']['target_variable']
    df[target_col] = df['NEXT_PRODUCT_ID']
    
    # Identify feature columns (exclude ID and target columns)
    id_cols = ['CUSTOMERID', 'PARTYID', 'NEXT_PRODUCT_ID', target_col]
    feature_cols = [col for col in df.columns if col not in id_cols]
    
    # Handle categorical columns (one-hot encoding)
    # Exclude interest rate columns - keep them as numeric
    categorical_cols = df[feature_cols].select_dtypes(include=['object', 'category']).columns.tolist()
    
    # Convert interest rate columns to numeric (they should not be one-hot encoded)
    interest_rate_cols = [col for col in categorical_cols if 'INTEREST_RATE' in col]
    if interest_rate_cols:
        logging.info(f"Converting {len(interest_rate_cols)} interest rate columns to numeric: {interest_rate_cols}")
        print(f"\n🔧 Converting {len(interest_rate_cols)} interest rate columns to numeric: {interest_rate_cols}")
        for col in interest_rate_cols:
            df[col] = pd.to_numeric(df[col], errors='coerce')
        # Remove from categorical list
        categorical_cols = [col for col in categorical_cols if col not in interest_rate_cols]
    
    if categorical_cols:
        logging.info(f"Encoding {len(categorical_cols)} categorical columns: {categorical_cols}")
        print(f"🔄 One-hot encoding {len(categorical_cols)} categorical columns: {categorical_cols}")
        df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)
        
        # FIX: Update feature columns after encoding (this was missing in original code)
        id_cols_set = set(id_cols)
        feature_cols = [col for col in df.columns if col not in id_cols_set]
        print(f"✅ Features after encoding: {len(feature_cols)} columns")
    
    X = df[feature_cols]
    y = df[target_col]
    
    print(f"\n✅ Final feature count: {X.shape[1]} (interest rates kept as numeric)")
    
    # Train-test split
    split_config = config['model']['train_test_split']
    test_size = split_config['test_size']
    random_state = split_config['random_state']
    stratify = y if split_config['stratify'] else None
    
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=random_state, stratify=stratify
    )
    
    logging.info(f"Train set: {len(X_train)} samples")
    logging.info(f"Test set: {len(X_test)} samples")
    logging.info(f"Number of features: {X_train.shape[1]}")
    logging.info(f"Number of classes: {y.nunique()}")
    
    return X_train, X_test, y_train, y_test

print("✅ Fixed prepare_training_data function loaded")
print("   - Interest rates will be kept as numeric (not one-hot encoded)")
print("   - Bug fix: feature_cols properly updated after encoding")
# Out:
# ✅ Fixed prepare_training_data function loaded
#    - Interest rates will be kept as numeric (not one-hot encoded)
#    - Bug fix: feature_cols properly updated after encoding

# %%
config = load_config('../config/config.yaml')

# Set MLflow tracking URI and experiment for local or databricks mode
if config['environment']['mode'] == 'databricks':
    # Use Databricks MLflow and set experiment name from config
    experiment_name = config['mlflow']['databricks']['experiment_name']
    mlflow.set_experiment(experiment_name)
    print(f'Using Databricks MLflow tracking.')
    print(f'Experiment: {experiment_name}')
else:
    # Set MLflow tracking to workspace root /mlruns directory
    workspace_root = os.path.abspath('..')
    mlflow_tracking_dir = os.path.join(workspace_root, 'mlruns')
    
    # For Windows, use file:/// with forward slashes
    mlflow_tracking_uri = 'file:///' + mlflow_tracking_dir.replace('\\', '/')
    
    mlflow.set_tracking_uri(mlflow_tracking_uri)
    
    experiment_name = config['mlflow']['local'].get('experiment_name', 'default')
    mlflow.set_experiment(experiment_name)
    
    print(f"📂 MLflow tracking URI: {mlflow_tracking_uri}")
    print(f"📂 MLflow runs will be saved to: {mlflow_tracking_dir}")
    print(f"Experiment: {experiment_name}")

setup_logging(config)

print_section_header("Model Training")

# Initialize MLflow client
mlflow_client = mlflow
# Out:
# Using Databricks MLflow tracking.
# Experiment: /Users/ashish.kamboj@tigeranalytics.com/next-best-product-recommendation
#
# ================================================================================
#                                  Model Training
# ================================================================================

# %% [markdown]
# ## 1. Load Features and Target

# %%
spark = None
if config['data_source']['type'] == 'unity_catalog':
    spark = get_spark_session(config)

# Load features and targets
if config['data_source']['type'] == 'unity_catalog':
    # Load from Unity Catalog Feature Store
    uc_config = config['data_source']['unity_catalog']
    catalog = uc_config['catalog']
    output_schema = uc_config['output_schema']
    
    # Try to load from Feature Store first, fallback to regular table
    try:
        from databricks.feature_engineering import FeatureEngineeringClient
        
        fe = FeatureEngineeringClient()
        
        feature_store_table = f"{catalog}.{output_schema}.customer_features_fs"
        target_table = f"{catalog}.{output_schema}.customer_targets"
        
        print(f"📊 Loading features from Feature Store: {feature_store_table}")
        print(f"📂 Loading targets from: {target_table}")
        
        # Load features from Feature Store
        features_df = fe.read_table(name=feature_store_table).toPandas()
        
        # Load targets from regular table
        target_df = spark.table(target_table).toPandas()
        
        print("✅ Using Databricks Feature Store for training")
        
    except ImportError:
        # Feature Store not available, use regular tables
        print("⚠️ Feature Store client not available, using regular Unity Catalog tables")
        
        features_table = f"{catalog}.{output_schema}.customer_features"
        target_table = f"{catalog}.{output_schema}.customer_targets"
        
        print(f"📂 Loading features from: {features_table}")
        print(f"📂 Loading targets from: {target_table}")
        
        features_df = spark.table(features_table).toPandas()
        target_df = spark.table(target_table).toPandas()
        
    except Exception as e:
        # Feature Store table doesn't exist, use regular tables
        print(f"⚠️ Feature Store table not found: {str(e)}")
        print("   Using regular Unity Catalog tables instead")
        
        features_table = f"{catalog}.{output_schema}.customer_features"
        target_table = f"{catalog}.{output_schema}.customer_targets"
        
        print(f"📂 Loading features from: {features_table}")
        print(f"📂 Loading targets from: {target_table}")
        
        features_df = spark.table(features_table).toPandas()
        target_df = spark.table(target_table).toPandas()
else:
    # CSV mode
    features_path = os.path.abspath('../data/processed/customer_features.csv')
    target_path = os.path.abspath('../data/processed/customer_targets.csv')
    print(f"📂 Loading features from: {features_path}")
    print(f"📂 Loading targets from: {target_path}")
    
    features_df = pd.read_csv(features_path)
    target_df = pd.read_csv(target_path)

logging.info(f"Loaded features: {features_df.shape}")
logging.info(f"Loaded targets: {target_df.shape}")

print(f"\n✅ Features loaded: {features_df.shape}")
print(f"✅ Targets loaded: {target_df.shape}")
# Out:
# 📊 Loading features from Feature Store: datafabric_catalog.ml_outputs.customer_features_fs
# 📂 Loading targets from: datafabric_catalog.ml_outputs.customer_targets
# ✅ Using Databricks Feature Store for training
#
# ✅ Features loaded: (1000, 43)
# ✅ Targets loaded: (467, 2)

# %% [markdown]
# ## 2. Prepare Training Data

# %%
# Check if data is valid
print(f"Features shape: {features_df.shape}")
print(f"Targets shape: {target_df.shape}")
print(f"Customers with features: {features_df['CUSTOMERID'].nunique()}")
print(f"Customers with targets: {target_df['CUSTOMERID'].nunique()}")
print(f"Targets with NEXT_PRODUCT_ID: {target_df['NEXT_PRODUCT_ID'].notna().sum()}")

# Check for common customers
common_customers = set(features_df['CUSTOMERID']).intersection(set(target_df['CUSTOMERID']))
print(f"Common customers: {len(common_customers)}")

if len(common_customers) == 0:
    raise ValueError("No common customers between features and targets! Please run 02_feature_engineering.ipynb first.")

# Check target distribution and filter out classes with too few samples
target_counts = target_df['NEXT_PRODUCT_ID'].value_counts()
classes_with_few_samples = target_counts[target_counts < 2].index.tolist()

if len(classes_with_few_samples) > 0:
    print(f"\n⚠️ Warning: Removing {len(classes_with_few_samples)} classes with < 2 samples: {classes_with_few_samples}")
    # Filter out these classes from target_df
    target_df = target_df[~target_df['NEXT_PRODUCT_ID'].isin(classes_with_few_samples)]
    print(f"Remaining targets: {target_df['NEXT_PRODUCT_ID'].notna().sum()}")

# Temporarily disable stratification if we still have too few samples
original_stratify = config['model']['train_test_split'].get('stratify', True)
if target_df['NEXT_PRODUCT_ID'].notna().sum() < 50:
    print("\n⚠️ Warning: Too few samples for stratification. Disabling stratify.")
    config['model']['train_test_split']['stratify'] = False

X_train, X_test, y_train, y_test = prepare_training_data(features_df, target_df, config)

# Restore original stratify setting
config['model']['train_test_split']['stratify'] = original_stratify

print(f"\n✅ Training set: {X_train.shape}")
print(f"✅ Test set: {X_test.shape}")
# Out:
# Features shape: (1000, 43)
# Targets shape: (467, 2)
# Customers with features: 1000
# Customers with targets: 467
# Targets with NEXT_PRODUCT_ID: 284
# Common customers: 467
#
# 🔧 Converting 2 interest rate columns to numeric: ['MIN_INTEREST_RATE', 'MAX_INTEREST_RATE']
# 🔄 One-hot encoding 2 categorical columns: ['AGE_GROUP', 'TENURE_GROUP']
# ✅ Features after encoding: 46 columns
#
# ✅ Final feature count: 46 (interest rates kept as numeric)
#
# ✅ Training set: (227, 46)
# ✅ Test set: (57, 46)

# %% [markdown]
# ## 3. Train Model

# %%
with Timer("Model Training"):
    # Get model
    model = get_model(config)
    
    # Train
    model = train_model(model, X_train, y_train)
    
    # Evaluate
    metrics = evaluate_model(model, X_test, y_test, config)
    
    # Feature importance
    feature_importance = get_feature_importance(model, X_train.columns.tolist())
    
    # Save feature importance plot as PNG
    if not feature_importance.empty:
        import os
        models_output_path = config.get('eda', {}).get('output_path', './outputs/models').replace('eda', 'models')
        if not os.path.isabs(models_output_path):
            models_output_path = os.path.abspath(os.path.join('..', models_output_path))
        os.makedirs(models_output_path, exist_ok=True)
        
        plot_path = os.path.join(models_output_path, 'feature_importance.png')
        plot_feature_importance(feature_importance, plot_path, top_n=20, algorithm=config['model']['algorithm'])
        print(f"📊 Feature importance plot saved to: {plot_path}")

print("\n✅ Model training completed!")
print(f"\n📊 Model trained with {X_train.shape[1]} features (interest rates as numeric)")
# Out:
# 📊 Feature importance plot saved to: /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/outputs/models/feature_importance.png
#
# ✅ Model training completed!
#
# 📊 Model trained with 46 features (interest rates as numeric)

# %% [markdown]
# ## 4. Log to MLflow

# %%
run_id = log_model_to_mlflow(
    model, X_train, metrics, feature_importance, config, mlflow_client
)

print(f"✅ Model logged to MLflow. Run ID: {run_id}")
# Out:
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-836ec205-447b-434f-80f6-9218e78ae5d4/lib/python3.10/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2025/12/02 12:03:16 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🔗 View Logged Model at: https://adb-1364099644588382.2.azuredatabricks.net/ml/experiments/2220209055559251/models/m-b371b339c7294134826d5382f4029091?o=1364099644588382
# 📊 Feature importance saved to: /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/outputs/models/feature_importance.csv
# ✅ Model logged to MLflow. Run ID: b5b7dcadd50b4c23aad9ace5dc793cf4

# %% [markdown]
# ## 5. Model Summary

# %%
print_section_header("Model Training Summary")

print(f"""
Algorithm: {config['model']['algorithm']}
Training samples: {len(X_train)}
Test samples: {len(X_test)}
Number of features: {X_train.shape[1]}
Number of classes: {len(np.unique(y_train))}

Model Performance Metrics:
""")

# Display standard metrics
print("\n📊 Classification Metrics:")
for metric, value in metrics.items():
    if value is not None and not metric.startswith('top_'):
        print(f"  {metric}: {value:.4f}")

# Display Top-K metrics separately
if any(k.startswith('top_') for k in metrics.keys()):
    print("\n🎯 Top-K Accuracy (Recommendation Metrics):")
    print("  (How often is the true product in top-K recommendations?)")
    for metric, value in metrics.items():
        if metric.startswith('top_') and value is not None:
            k_value = metric.split('_')[1]
            print(f"  {metric}: {value:.4f} ({value*100:.1f}% - true product in top-{k_value})")

print(f"\n📈 Feature Importance:")
print(f"Top 10 Important Features:")
print(feature_importance.head(10).to_string(index=False))

print(f"\nMLflow Run ID: {run_id}")

print("\n✅ Model training completed!")
# Out:
# ================================================================================
#                              Model Training Summary
# ================================================================================
#
#
# Algorithm: xgboost
# Training samples: 227
# Test samples: 57
# Number of features: 46
# Number of classes: 10
#
# Model Performance Metrics:
#
#
# 📊 Classification Metrics:
#   accuracy: 0.1053
#   precision_weighted: 0.1155
#   recall_weighted: 0.1053
#   f1_weighted: 0.1057
#   roc_auc_ovr: 0.4963
#
# 🎯 Top-K Accuracy (Recommendation Metrics):
#   (How often is the true product in top-K recommendations?)
#   top_1_accuracy: 0.0000 (0.0% - true product in top-1)
#   top_3_accuracy: 0.0000 (0.0% - true product in top-3)
#   top_5_accuracy: 0.0000 (0.0% - true product in top-5)
#
# 📈 Feature Importance:
# Top 10 Important Features:
#                    feature  importance
#   TXN_AMOUNT_STD_LONG_TERM    0.048479
#  TXN_AMOUNT_MEAN_LONG_TERM    0.047423
#   TXN_AMOUNT_MAX_LONG_TERM    0.036901
#      TXN_COUNT_MEDIUM_TERM    0.033900
# TXN_AMOUNT_MIN_MEDIUM_TERM    0.027192
#   TXN_AMOUNT_SUM_LONG_TERM    0.024215
#             TOTAL_ACCOUNTS    0.024166
# TXN_AMOUNT_MAX_MEDIUM_TERM    0.023607
#  TXN_AMOUNT_MAX_SHORT_TERM    0.022975
#         TENURE_GROUP_6M-1Y    0.022705
#
# MLflow Run ID: b5b7dcadd50b4c23aad9ace5dc793cf4
#
# ✅ Model training completed!
