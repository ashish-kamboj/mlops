# %%
# Fix typing_extensions version issue first
# The Sentinel class was added in typing_extensions 4.6.0
# %pip install --upgrade typing_extensions>=4.6.0 pydantic>=2.0.0 --quiet

# Install Azure dependencies for Unity Catalog
# %pip install azure-storage-file-datalake azure-identity azure-core --quiet

# Install Databricks Feature Engineering for Feature Store
# %pip install databricks-feature-engineering --quiet

# Install project requirements
# !pip install -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt

# Restart Python kernel to use updated packages
dbutils.library.restartPython()
# Out:
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: numpy==1.26.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: pandas==2.3.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 3)) (2.3.3)
# Requirement already satisfied: scikit-learn==1.7.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 4)) (1.7.2)
# Requirement already satisfied: matplotlib==3.10.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (3.10.7)
# Requirement already satisfied: seaborn==0.13.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 6)) (0.13.2)
# Requirement already satisfied: plotly==5.24.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 7)) (5.24.1)
# Requirement already satisfied: pyyaml==6.0.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 8)) (6.0.3)
# Requirement already satisfied: pyarrow==20.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 9)) (20.0.0)
# Requirement already satisfied: mlflow==3.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.0.1)
# Requirement already satisfied: shap==0.49.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (0.49.1)
# Requirement already satisfied: xgboost==2.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 23)) (2.1.0)
# Requirement already satisfied: evidently==0.6.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.6.1)
# Requirement already satisfied: python-dateutil==2.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 30)) (2.9.0)
# Requirement already satisfied: tqdm==4.67.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 31)) (4.67.1)
# Requirement already satisfied: joblib==1.5.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 32)) (1.5.2)
# Requirement already satisfied: papermill==2.5.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from -r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (2.5.0)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.10/site-packages (from pandas==2.3.3->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 3)) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from pandas==2.3.3->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in /databricks/python3/lib/python3.10/site-packages (from scikit-learn==1.7.2->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 4)) (1.10.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from scikit-learn==1.7.2->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: pillow>=8 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (1.0.5)
# Requirement already satisfied: pyparsing>=3 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (23.2)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.10/site-packages (from matplotlib==3.10.7->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: tenacity>=6.2.0 in /databricks/python3/lib/python3.10/site-packages (from plotly==5.24.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 7)) (8.1.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.0.44)
# Requirement already satisfied: graphene<4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.4.3)
# Requirement already satisfied: docker<8,>=4.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (7.1.0)
# Requirement already satisfied: gunicorn<24 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (23.0.0)
# Requirement already satisfied: alembic!=1.10.0,<2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.17.2)
# Requirement already satisfied: mlflow-skinny==3.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.0.1)
# Requirement already satisfied: Flask<4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.3.3)
# Requirement already satisfied: typing-extensions in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (4.15.0)
# Requirement already satisfied: cloudpickle in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (3.1.2)
# Requirement already satisfied: slicer==0.0.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (0.62.1)
# Requirement already satisfied: nvidia-nccl-cu12 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from xgboost==2.1.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 23)) (2.28.9)
# Requirement already satisfied: cryptography>=43.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (46.0.3)
# Requirement already satisfied: typing-inspect>=0.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.9.0)
# Requirement already satisfied: requests>=2.32.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.32.5)
# Requirement already satisfied: ujson>=5.4.0 in /databricks/python3/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (5.4.0)
# Requirement already satisfied: uvicorn[standard]>=0.22.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.38.0)
# Requirement already satisfied: pydantic>=1.10.13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.12.5)
# Requirement already satisfied: statsmodels>=0.12.2 in /databricks/python3/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.13.5)
# Requirement already satisfied: certifi>=2024.7.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2025.11.12)
# Requirement already satisfied: dynaconf>=3.2.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.2.12)
# Requirement already satisfied: iterative-telemetry>=0.0.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.0.10)
# Requirement already satisfied: typer>=0.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.20.0)
# Requirement already satisfied: deprecation>=2.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.1.0)
# Requirement already satisfied: watchdog>=3.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (6.0.0)
# Requirement already satisfied: litestar>=2.8.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.18.0)
# Requirement already satisfied: urllib3>=1.26.19 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.26.20)
# Requirement already satisfied: uuid6>=2024.7.10 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2025.0.1)
# Requirement already satisfied: fsspec>=2024.6.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2025.10.0)
# Requirement already satisfied: nltk>=3.6.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.9.2)
# Requirement already satisfied: rich>=13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (14.2.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil==2.9.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 30)) (1.16.0)
# Requirement already satisfied: click in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (8.3.1)
# Requirement already satisfied: nbformat>=5.1.2 in /databricks/python3/lib/python3.10/site-packages (from papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (5.7.0)
# Requirement already satisfied: entrypoints in /databricks/python3/lib/python3.10/site-packages (from papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (0.4)
# Requirement already satisfied: nbclient>=0.2.0 in /databricks/python3/lib/python3.10/site-packages (from papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (0.5.13)
# Requirement already satisfied: fastapi<1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.121.3)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.38.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.5.3)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.1.45)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (6.33.1)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /databricks/python3/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (5.3.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.73.0)
# Requirement already satisfied: tomli in /databricks/python3/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.0.1)
# Requirement already satisfied: Mako in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.3.10)
# Requirement already satisfied: cffi>=2.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from cryptography>=43.0.1->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.0.0)
# Requirement already satisfied: blinker>=1.6.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (1.9.0)
# Requirement already satisfied: Werkzeug>=2.3.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /databricks/python3/lib/python3.10/site-packages (from Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.2.0)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from graphene<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.2.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from graphene<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.2.7)
# Requirement already satisfied: filelock in /databricks/python3/lib/python3.10/site-packages (from iterative-telemetry>=0.0.5->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.16.1)
# Requirement already satisfied: distro in /usr/lib/python3/dist-packages (from iterative-telemetry>=0.0.5->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.7.0)
# Requirement already satisfied: appdirs in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from iterative-telemetry>=0.0.5->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.4.4)
# Requirement already satisfied: rich-click in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.9.4)
# Requirement already satisfied: litestar-htmx>=0.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.5.0)
# Requirement already satisfied: httpx>=0.22 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.28.1)
# Requirement already satisfied: anyio>=3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (4.11.0)
# Requirement already satisfied: multidict>=6.0.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (6.7.0)
# Requirement already satisfied: polyfactory>=2.6.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.0.0)
# Requirement already satisfied: exceptiongroup in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.3.0)
# Requirement already satisfied: msgspec>=0.18.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.19.0)
# Requirement already satisfied: multipart>=1.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.3.0)
# Requirement already satisfied: traitlets>=5.0.0 in /databricks/python3/lib/python3.10/site-packages (from nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (5.7.1)
# Requirement already satisfied: jupyter-client>=6.1.5 in /databricks/python3/lib/python3.10/site-packages (from nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (7.3.4)
# Requirement already satisfied: nest-asyncio in /databricks/python3/lib/python3.10/site-packages (from nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (1.5.6)
# Requirement already satisfied: jupyter-core in /databricks/python3/lib/python3.10/site-packages (from nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (5.2.0)
# Requirement already satisfied: jsonschema>=2.6 in /databricks/python3/lib/python3.10/site-packages (from nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (4.17.3)
# Requirement already satisfied: fastjsonschema in /databricks/python3/lib/python3.10/site-packages (from nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (2.20.0)
# Requirement already satisfied: regex>=2021.8.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from nltk>=3.6.7->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2025.11.3)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from numba>=0.54->shap==0.49.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 20)) (0.45.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from pydantic>=1.10.13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from pydantic>=1.10.13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.4.2)
# Requirement already satisfied: pydantic-core==2.41.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from pydantic>=1.10.13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.41.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.32.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.32.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (3.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from rich>=13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from rich>=13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.19.2)
# Requirement already satisfied: greenlet>=1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.2.4)
# Requirement already satisfied: patsy>=0.5.2 in /databricks/python3/lib/python3.10/site-packages (from statsmodels>=0.12.2->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.5.3)
# Requirement already satisfied: shellingham>=1.3.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from typer>=0.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /databricks/python3/lib/python3.10/site-packages (from typing-inspect>=0.9.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.4.3)
# Requirement already satisfied: h11>=0.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.16.0)
# Requirement already satisfied: python-dotenv>=0.13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.2.1)
# Requirement already satisfied: httptools>=0.6.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in /databricks/python3/lib/python3.10/site-packages (from anyio>=3->litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.2.0)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography>=43.0.1->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (2.21)
# Requirement already satisfied: google-auth~=2.0 in /databricks/python3/lib/python3.10/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.28.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.0.4)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.50.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (4.0.12)
# Requirement already satisfied: httpcore==1.* in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from httpx>=0.22->litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (1.0.9)
# Requirement already satisfied: zipp>=3.20 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.10/site-packages (from Jinja2>=3.1.2->Flask<4->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (2.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /databricks/python3/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /databricks/python3/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (22.1.0)
# Requirement already satisfied: tornado>=6.0 in /databricks/python3/lib/python3.10/site-packages (from jupyter-client>=6.1.5->nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (6.1)
# Requirement already satisfied: pyzmq>=23.0 in /databricks/python3/lib/python3.10/site-packages (from jupyter-client>=6.1.5->nbclient>=0.2.0->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (23.2.0)
# Requirement already satisfied: platformdirs>=2.5 in /databricks/python3/lib/python3.10/site-packages (from jupyter-core->nbformat>=5.1.2->papermill==2.5.0->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 33)) (2.5.2)
# Requirement already satisfied: mdurl~=0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (0.1.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.59b0)
# Requirement already satisfied: faker>=5.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from polyfactory>=2.6.3->litestar>=2.8.3->evidently==0.6.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 27)) (38.2.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-82dbe1ea-e825-49b9-9d4d-86cb2267511d/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /databricks/python3/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /databricks/python3/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (4.9)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /databricks/python3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.0.1->mlflow==3.0.1->-r /Workspace/Users/ashish.kamboj@tigeranalytics.com/home-credit-hyperpersonalization/requirements.txt (line 17)) (0.5.1)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import sys
import os
import logging
import pandas as pd

# Dynamically determine project root
project_root = os.path.dirname(os.getcwd()) if os.getcwd().endswith('notebooks') else os.getcwd()
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# Import utils modules
from utils.common_utils import load_config, setup_logging, get_spark_session, print_section_header, Timer
from utils.data_loader import load_data_from_source
from utils.model_deployment import load_model_from_registry, batch_predict, save_predictions

import mlflow

print("✅ All modules imported successfully")
# Out:
# ✅ All modules imported successfully

# %%
config = load_config('../config/config.yaml')
setup_logging(config)

print_section_header("Batch Inference")
# Out:
# ================================================================================
#                                 Batch Inference
# ================================================================================

# %% [markdown]
# ## 1. Load Production Model

# %%
model_name = config['mlflow']['databricks']['registered_model_name'] if config['environment']['mode'] == 'databricks' else config['mlflow']['local']['registered_model_name']

# Set MLflow tracking URI to correct location (workspace root, not notebooks folder)
import os
env_mode = config['environment']['mode']
if env_mode == 'databricks':
    tracking_uri = config['mlflow']['databricks']['tracking_uri']
else:
    # For local mode, resolve to workspace root
    tracking_uri_relative = config['mlflow']['local']['tracking_uri']
    cwd = os.getcwd()
    if cwd.endswith('notebooks'):
        workspace_root = os.path.dirname(cwd)
    else:
        workspace_root = cwd
    tracking_path = os.path.join(workspace_root, tracking_uri_relative.lstrip('./'))
    tracking_uri = 'file:///' + tracking_path.replace('\\', '/')

mlflow.set_tracking_uri(tracking_uri)
print(f"🔍 MLflow tracking URI: {tracking_uri}")

# Create MLflow client
mlflow_client = mlflow.MlflowClient()

if env_mode == 'databricks':
    # Unity Catalog: use aliases instead of stages
    print(f"\nChecking Unity Catalog model: {model_name}")
    
    # Try to get model version by 'production' alias
    try:
        production_version = mlflow_client.get_model_version_by_alias(model_name, 'production')
        print(f"✅ Found model with 'production' alias: Version {production_version.version}")
        
        # Load model using sklearn loader to get predict_proba method
        model_uri = f"models:/{model_name}@production"
        model = mlflow.sklearn.load_model(model_uri)
        print(f"✅ Model loaded successfully from alias 'production' (sklearn model)")
        
    except Exception as e:
        # If no production alias, show available versions and aliases
        print(f"❌ No model found with 'production' alias")
        print(f"\nAvailable model versions:")
        
        all_versions = mlflow_client.search_model_versions(f"name='{model_name}'")
        for v in sorted(all_versions, key=lambda x: int(x.version)):
            version_details = mlflow_client.get_model_version(model_name, v.version)
            aliases = version_details.aliases if hasattr(version_details, 'aliases') else []
            print(f"  Version {v.version}: Aliases={aliases}, Status={v.status}")
        
        error_msg = f"""
❌ No model found with 'production' alias!
   
   To set the 'production' alias:
   1. Go to 04_model_deployment.ipynb
   2. Run cell 15 (manual promotion) to set 'production' alias
   OR
   3. Run cell 6 above in this notebook to quick-promote
   
   Batch inference REQUIRES a 'production' alias for safety and governance.
"""
        print(error_msg)
        raise ValueError("No Production model available. Please set 'production' alias first.")
        
else:
    # Local MLflow: use traditional stages
    versions = mlflow_client.get_latest_versions(model_name)
    production_versions = [v for v in versions if v.current_stage == 'Production']
    
    print(f"\nAvailable model versions:")
    for v in versions:
        print(f"  Version {v.version}: Stage={v.current_stage}")
    
    if not production_versions:
        error_msg = f"""
❌ No model found in Production stage!
   
   Available versions: {[(v.version, v.current_stage) for v in versions]}
   
   To promote a model to Production:
   1. Go to 04_model_deployment.ipynb
   2. Run the manual promotion cell (section 3c)
   OR
   3. Run cell 6 above in this notebook to quick-promote from Staging
   
   Batch inference REQUIRES a Production model for safety and governance.
"""
        print(error_msg)
        raise ValueError("No Production model available. Please promote a model to Production first.")
    
    print(f"\n✅ Found model in Production stage (Version {production_versions[0].version})")
    model = load_model_from_registry(model_name, stage='Production', config=config)
    print(f"✅ Model loaded successfully from registry")
# Out:
# 🔍 MLflow tracking URI: databricks
#
# Checking Unity Catalog model: datafabric_catalog.customer_hc_silver.next_best_product_model
# ✅ Found model with 'production' alias: Version 5
# Downloading artifacts:   0%|          | 0/12 [00:00<?, ?it/s]
# ✅ Model loaded successfully from alias 'production' (sklearn model)

# %% [markdown]
# ## 2. Load Customer Features and Filter for Inference

# %%
spark = None
if config['data_source']['type'] == 'unity_catalog':
    spark = get_spark_session(config)

# Load features from Feature Store and targets from Unity Catalog
if config['data_source']['type'] == 'unity_catalog':
    uc_config = config['data_source']['unity_catalog']
    catalog = uc_config['catalog']
    output_schema = uc_config['output_schema']
    
    # Load features from Feature Store
    feature_store_table = f"{catalog}.{output_schema}.customer_features_fs"
    target_table = f"{catalog}.{output_schema}.customer_targets"
    
    print(f"📊 Loading features from Feature Store: {feature_store_table}")
    print(f"📂 Loading targets from: {target_table}")
    
    try:
        from databricks.feature_engineering import FeatureEngineeringClient
        
        fe = FeatureEngineeringClient()
        
        # Read features from Feature Store
        features_spark_df = fe.read_table(name=feature_store_table)
        features_df = features_spark_df.toPandas()
        
        print(f"✅ Loaded features from Feature Store")
        
    except ImportError:
        print(f"⚠️ Feature Engineering client not available, falling back to direct table read")
        features_table = f"{catalog}.{output_schema}.customer_features"
        features_df = spark.table(features_table).toPandas()
        print(f"✅ Loaded features from Unity Catalog table: {features_table}")
    
    except Exception as e:
        print(f"⚠️ Error reading from Feature Store: {str(e)}")
        print(f"   Falling back to direct table read")
        features_table = f"{catalog}.{output_schema}.customer_features"
        features_df = spark.table(features_table).toPandas()
        print(f"✅ Loaded features from Unity Catalog table: {features_table}")
    
    # Load targets from Unity Catalog
    target_df = spark.table(target_table).toPandas()
    
else:
    # CSV mode
    features_path = os.path.abspath('../data/processed/customer_features.csv')
    target_path = os.path.abspath('../data/processed/customer_targets.csv')
    print(f"📂 Loading features from: {features_path}")
    print(f"📂 Loading targets from: {target_path}")
    
    features_df = pd.read_csv(features_path)
    target_df = pd.read_csv(target_path)

print(f"✅ Loaded features for {len(features_df)} customers")

# Filter to ONLY customers who DON'T have a target (never purchased next product)
# These customers were NOT used in model training - true inference scenario
customers_with_target = target_df[target_df['NEXT_PRODUCT_ID'].notna()]['CUSTOMERID'].unique()
features_df = features_df[~features_df['CUSTOMERID'].isin(customers_with_target)].copy()

print(f"✅ Filtered to {len(features_df)} customers WITHOUT target (true inference set)")
print(f"   These customers were NEVER used in model training")
# Out:
# 📊 Loading features from Feature Store: datafabric_catalog.ml_outputs.customer_features_fs
# 📂 Loading targets from: datafabric_catalog.ml_outputs.customer_targets
# ✅ Loaded features from Feature Store
# ✅ Loaded features for 1000 customers
# ✅ Filtered to 716 customers WITHOUT target (true inference set)
#    These customers were NEVER used in model training

# %% [markdown]
# ## 3. Generate Predictions

# %%
# Prepare features (match training format)
customer_ids = features_df['CUSTOMERID']
X = features_df.drop(['CUSTOMERID', 'PARTYID'], axis=1, errors='ignore')

# Handle categorical encoding (same as training)
categorical_cols = X.select_dtypes(include=['object', 'category']).columns.tolist()
if categorical_cols:
    X = pd.get_dummies(X, columns=categorical_cols, drop_first=True)

print(f"Features after encoding: {X.shape}")

# Align features with training data
# Get expected feature names from the model
if hasattr(model, 'feature_names_in_'):
    expected_features = model.feature_names_in_
    print(f"Model expects {len(expected_features)} features")
    
    # Add missing columns with 0 values
    missing_cols = set(expected_features) - set(X.columns)
    if missing_cols:
        print(f"Adding {len(missing_cols)} missing columns with 0 values")
        for col in missing_cols:
            X[col] = 0
    
    # Remove extra columns not in training
    extra_cols = set(X.columns) - set(expected_features)
    if extra_cols:
        print(f"Removing {len(extra_cols)} extra columns not in training")
        X = X.drop(columns=list(extra_cols))
    
    # Reorder columns to match training
    X = X[expected_features]
    print(f"Features aligned: {X.shape}")
else:
    print("⚠️ Warning: Model doesn't have feature_names_in_ attribute. Proceeding without alignment.")

# Generate top-K predictions
with Timer("Batch Prediction"):
    top_k = config['deployment']['batch_inference']['top_k_recommendations']
    predictions_df = batch_predict(model, X, customer_ids, config, top_k=top_k)

print(f"\n✅ Generated {len(predictions_df)} recommendations for {len(customer_ids)} customers")
# Out:
# Features after encoding: (716, 298)
# Model expects 46 features
# Adding 2 missing columns with 0 values
# Removing 254 extra columns not in training
# Features aligned: (716, 46)
#
# ✅ Generated 2148 recommendations for 716 customers

# %%
# Load products table
if config['data_source']['type'] == 'unity_catalog':
    products_df = load_data_from_source(config, 'banking_product', spark)
else:
    products_path = os.path.abspath('../data/raw/banking_product.csv')
    products_df = pd.read_csv(products_path)

products_df.columns = products_df.columns.str.upper()

# Create mapping: class label (0-9) -> actual product ID (101-110)
unique_product_ids = sorted(target_df['NEXT_PRODUCT_ID'].dropna().unique())
class_to_product_id = {i: int(pid) for i, pid in enumerate(unique_product_ids)}

# Map predicted class labels to actual product IDs
predictions_df['PREDICTED_PRODUCT_ID'] = predictions_df['PREDICTED_PRODUCT_ID'].map(class_to_product_id)

# Merge with products to get product names
predictions_df = predictions_df.merge(
    products_df[['PRODUCTID', 'PRODUCTNAME']], 
    left_on='PREDICTED_PRODUCT_ID', 
    right_on='PRODUCTID', 
    how='left'
).drop(columns=['PRODUCTID'])

# Reorder columns
column_order = ['CUSTOMERID', 'RANK', 'PREDICTED_PRODUCT_ID', 'PRODUCTNAME', 'PROBABILITY', 'PREDICTION_TIMESTAMP']
predictions_df = predictions_df[column_order]

print(f"✅ Product names added to {len(predictions_df)} predictions")
print(f"\nSample recommendations:")
print(predictions_df.head(9).to_string(index=False))
# Out:
# ✅ Product names added to 2148 predictions
#
# Sample recommendations:
#  CUSTOMERID  RANK  PREDICTED_PRODUCT_ID            PRODUCTNAME  PROBABILITY       PREDICTION_TIMESTAMP
#        1001     1                   103     60-Month Auto Loan     0.270500 2025-12-02 15:18:13.150230
#        1001     2                   108           RV/Boat Loan     0.180267 2025-12-02 15:18:13.150230
#        1001     3                   107 Student Refinance Loan     0.162612 2025-12-02 15:18:13.150230
#        1002     1                   101 30-Year Fixed Mortgage     0.213071 2025-12-02 15:18:13.150230
#        1002     2                   103     60-Month Auto Loan     0.186766 2025-12-02 15:18:13.150230
#        1002     3                   107 Student Refinance Loan     0.147714 2025-12-02 15:18:13.150230
#        1003     1                   108           RV/Boat Loan     0.663767 2025-12-02 15:18:13.150230
#        1003     2                   107 Student Refinance Loan     0.083175 2025-12-02 15:18:13.150230
#        1003     3                   103     60-Month Auto Loan     0.077590 2025-12-02 15:18:13.150230

# %% [markdown]
# ## 4. Save Predictions

# %%
# Save predictions to outputs/predictions folder
import os
from utils.data_loader import save_data_to_destination

# Resolve to workspace root
workspace_root = os.path.dirname(os.getcwd()) if os.getcwd().endswith('notebooks') else os.getcwd()
predictions_output_path = os.path.join(workspace_root, 'outputs', 'predictions')
os.makedirs(predictions_output_path, exist_ok=True)

# Save predictions
if config['data_source']['type'] == 'unity_catalog':
    save_predictions(predictions_df, config, spark)
    print(f"✅ Predictions saved to Unity Catalog")
else:
    save_data_to_destination(predictions_df, config, 'product_recommendations', 
                             spark=None, mode='overwrite', output_path=predictions_output_path)
    print(f"✅ Predictions saved to: {os.path.join(predictions_output_path, 'product_recommendations.csv')}")
# Out:
# ✅ Predictions saved to Unity Catalog

# %% [markdown]
# ## 5. Prediction Summary

# %%
print_section_header("Batch Inference Summary")

print(f"""
Total Customers Scored: {len(customer_ids)}
Total Recommendations: {len(predictions_df)}
Top-K per Customer: {top_k}

Sample Recommendations:
""")

print(predictions_df.head(10).to_string(index=False))

print(f"\n✅ Batch inference completed!")
# Out:
# ================================================================================
#                             Batch Inference Summary
# ================================================================================
#
#
# Total Customers Scored: 716
# Total Recommendations: 2148
# Top-K per Customer: 3
#
# Sample Recommendations:
#
#  CUSTOMERID  RANK  PREDICTED_PRODUCT_ID            PRODUCTNAME  PROBABILITY       PREDICTION_TIMESTAMP
#        1001     1                   103     60-Month Auto Loan     0.270500 2025-12-02 15:18:13.150230
#        1001     2                   108           RV/Boat Loan     0.180267 2025-12-02 15:18:13.150230
#        1001     3                   107 Student Refinance Loan     0.162612 2025-12-02 15:18:13.150230
#        1002     1                   101 30-Year Fixed Mortgage     0.213071 2025-12-02 15:18:13.150230
#        1002     2                   103     60-Month Auto Loan     0.186766 2025-12-02 15:18:13.150230
#        1002     3                   107 Student Refinance Loan     0.147714 2025-12-02 15:18:13.150230
#        1003     1                   108           RV/Boat Loan     0.663767 2025-12-02 15:18:13.150230
#        1003     2                   107 Student Refinance Loan     0.083175 2025-12-02 15:18:13.150230
#        1003     3                   103     60-Month Auto Loan     0.077590 2025-12-02 15:18:13.150230
#        1004     1                   108           RV/Boat Loan     0.384720 2025-12-02 15:18:13.150230
#
# ✅ Batch inference completed!
